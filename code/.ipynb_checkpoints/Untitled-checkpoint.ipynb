# %%
import sys
sys.path.append('./')
import layout
import utils

import numpy as np
import pandas as pd

# %%
items_df = pd.read_csv('../artifacts/top_100_sku.csv')
set_items = set(items_df['sku'].values.tolist())

# %%
len(set_items)
# Out:
# 100

# %%
top_25_items_set = set(pd.read_csv('../artifacts/top_items_together.txt')['sku'].tolist())

# %%
len(top_25_items_set)
# Out:
# 25

# %%
top_25_items_set - set_items
# Out:
# {901059, 901060, 901061, 901067, 901068, 901069, 902438, 911091, 911092}

# %%
orders_df = pd.read_csv('../artifacts/random_100_orders.csv')

# %%
temp_list = []
for _,row in orders_df.iterrows():
    temp_list += row['sku'].split(',')
order_items_set = set(temp_list)

# %%
len(order_items_set)
# Out:
# 446

# %%
order_items_set
# Out:
# {'900046',
#  '900061',
#  '900062',
#  '900071',
#  '900087',
#  '900116',
#  '900126',
#  '900127',
#  '900134',
#  '900135',
#  '900136',
#  '900152',
#  '900220',
#  '900279',
#  '900297',
#  '900330',
#  '900334',
#  '900338',
#  '900339',
#  '900340',
#  '900341',
#  '900344',
#  '900345',
#  '900349',
#  '900350',
#  '900351',
#  '900352',
#  '900353',
#  '900354',
#  '900356',
#  '900385',
#  '900393',
#  '900416',
#  '900436',
#  '900437',
#  '900439',
#  '900442',
#  '900443',
#  '900451',
#  '900492',
#  '900502',
#  '900504',
#  '900510',
#  '900511',
#  '900516',
#  '900540',
#  '900579',
#  '900581',
#  '900592',
#  '900737',
#  '900776',
#  '900955',
#  '900958',
#  '900985',
#  '901059',
#  '901061',
#  '901065',
#  '901067',
#  '901070',
#  '901071',
#  '901074',
#  '901075',
#  '901076',
#  '901077',
#  '901078',
#  '901082',
#  '901108',
#  '901118',
#  '901120',
#  '901125',
#  '901127',
#  '901134',
#  '901141',
#  '901155',
#  '901163',
#  '901209',
# ...

# %%
together_sku_set = top_25_items_set.intersection(set_items)

# %%
overall_items = together_sku_set.union(set_items-top_25_items_set)

# %%
len(overall_items)
# Out:
# 100

# %%
l_obj = layout.layout('../layout_files/row_layout_100.txt')
